# %% [markdown]
# topic of the report is about changes in counts of crimes that have been recorded by the police
# in West Yorkshire over six months between April and September 2020
#
# - how did counts of the different types of crime change over the 6 month period?
#
# - Are the patterns as you would expect?
#
# - In addition, highlight any unexpected or unusual features of the data. Is there anything to suggest that their data are incomplete, incorrect, etc.?
#
# - And can you be confident that your work is correct? Finally, they would also like your thoughts on
#
# - what else you might like to do with their data if you had more time.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
april = pd.read_csv("C:\\Users\\Eunice\\Documents\\LIDA\\crime_data\\data\\2020-04\\2020-04-west-yorkshire-street.csv")
may = pd.read_csv("C:\\Users\\Eunice\\Documents\\LIDA\\crime_data\\data\\2020-05\\2020-05-west-yorkshire-street.csv")
june = pd.read_csv("C:\\Users\\Eunice\\Documents\\LIDA\\crime_data\\data\\2020-06\\2020-06-west-yorkshire-street.csv")
july = pd.read_csv("C:\\Users\\Eunice\\Documents\\LIDA\\crime_data\\data\\2020-07\\2020-07-west-yorkshire-street.csv")
aug = pd.read_csv("C:\\Users\\Eunice\\Documents\\LIDA\\crime_data\\data\\2020-08\\2020-08-west-yorkshire-street.csv")
sep = pd.read_csv("C:\\Users\\Eunice\\Documents\\LIDA\\crime_data\\data\\2020-09\\2020-09-west-yorkshire-street.csv")

# %%
april.shape
# Out:
# (21785, 12)

# %%
may.shape
# Out:
# (24657, 13)

# %%
june.shape
# Out:
# (26730, 13)

# %%
july.shape
# Out:
# (29278, 12)

# %%
aug.shape
# Out:
# (29433, 13)

# %%
sep.shape
# Out:
# (27015, 13)

# %%
april.head()
# Out:
#    Unnamed: 0                                           Crime ID    Month  \
# 0           0                                                NaN  2020-04
# 1           1  5ea1997471c9de64fcfcf1145cadfff71ba37f21668d25...  2020-04
# 2           2                                                NaN  2020-04
# 3           3  0d8ee70dbd3096b4d07059d7f7c310fbf5de9cb7d44c31...  2020-04
# 4           4  cb4709a03d98dc63ba4c1771171bc7a9353097f5851d80...  2020-04
#
#             Falls within  Longitude   Latitude                      Location  \
# 0  West Yorkshire Police  -1.550626  53.597400       On or near Swithen Hill
# 1  West Yorkshire Police  -1.670108  53.553629  On or near Huddersfield Road
# 2  West Yorkshire Police  -1.862742  53.940068     On or near Smithy Greaves
# 3  West Yorkshire Police  -1.879031  53.943807     On or near Cross End Fold
# 4  West Yorkshire Police  -1.882481  53.924936      On or near Moorside Lane
#
# ...

# %%
may.head()
# Out:
#    Unnamed: 0                                           Crime ID    Month  \
# 0           0  9e590d60c84d9ba7e23a29010de14b44c6eead68244ac9...  2020-05
# 1           1  472dce151845a2dda9743bb01df3023f43e65137eb8409...      NaN
# 2           2  49ae8c6359c39f298f397c5a0cd40f94e3313f30ef1645...  2020-05
# 3           3                                                NaN  2020-05
# 4           4  a2f402413366d3fb5ff3c878685eeca8980dc0cb01c581...  2020-05
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  West Yorkshire Police  West Yorkshire Police  -1.409547  53.598298
# 1                    NaN                    NaN        NaN        NaN
# 2  West Yorkshire Police  West Yorkshire Police  -1.570572  53.607792
# 3  West Yorkshire Police  West Yorkshire Police  -1.882481  53.924936
# 4  West Yorkshire Police  West Yorkshire Police  -1.862742  53.940068
#
#                      Location  LSOA code      LSOA name  \
# ...

# %%
june.head()
# Out:
#    Unnamed: 0                                           Crime ID    Month  \
# 0           0  9cfc0ed854bc20e2402d91de03c01bb0eec53ca7d1e52f...  2020-06
# 1           1  e8ef06134d7cbd661b44b14b0090f533d767b1c56702fc...  2020-06
# 2           2                                                NaN  2020-06
# 3           3                                                NaN  2020-06
# 4           4                                                NaN  2020-06
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  West Yorkshire Police  West Yorkshire Police  -1.764583  53.534617
# 1  West Yorkshire Police  West Yorkshire Police  -1.764583  53.534617
# 2  West Yorkshire Police  West Yorkshire Police  -1.873004  53.941724
# 3  West Yorkshire Police  West Yorkshire Police  -1.882481  53.924936
# 4  West Yorkshire Police  West Yorkshire Police  -1.873004  53.941724
#
#                         Location  LSOA code      LSOA name  \
# ...

# %%
july.head()
# Out:
#    Unnamed: 0                                           Crime ID    Month  \
# 0           0                                                NaN  2020-07
# 1           1  50395ea7c80fde52314573938fad186de8f4118fe74260...  2020-07
# 2           2  4f60c5874d85ca077f35667c8d56ce05faf5927d3163cf...  2020-07
# 3           3                                                NaN  2020-07
# 4           4  52db44fce1fa3724e549374d219cc4d8c348396d68a66c...  2020-07
#
#              Reported by  Longitude   Latitude                      Location  \
# 0  West Yorkshire Police  -1.540822  53.573544                 On or near M1
# 1  West Yorkshire Police  -1.513406  53.525383    On or near Park/Open Space
# 2  West Yorkshire Police  -1.670108  53.553629  On or near Huddersfield Road
# 3  West Yorkshire Police  -1.862972  53.939790         On or near Holme Ings
# 4  West Yorkshire Police  -1.875495  53.944297        On or near Wharfe Park
#
#    LSOA code      LSOA name                 Crime type  \
# ...

# %%
aug.head()
# Out:
#    Unnamed: 0                                           Crime ID    Month  \
# 0           0                                                NaN  2020-08
# 1           1                                                NaN  2020-08
# 2           2  ecd8aa122d281f2cea374add4c4c6b99116edc9cd33a07...  2020-08
# 3           3                                                NaN  2020-08
# 4           4  e5868a277479a8b0635e798c65c8cacd14d04b6dcb2901...  2020-08
#
#              Reported by           Falls within  Longitude   Latitude  \
# 0  West Yorkshire Police  West Yorkshire Police  -1.706334  53.549364
# 1  West Yorkshire Police  West Yorkshire Police  -1.877602  53.947814
# 2  West Yorkshire Police  West Yorkshire Police  -1.882481  53.924936
# 3  West Yorkshire Police  West Yorkshire Police  -1.883296  53.943901
# 4  West Yorkshire Police  West Yorkshire Police  -1.883511  53.943550
#
#                        Location  LSOA code      LSOA name  \
# ...

# %%
sep.head()

# %%
crime_join = [april, may, june, july, aug, sep]

crime = pd.concat(frames)
crime
# Out:
#        Unnamed: 0                                           Crime ID    Month  \
# 0               0                                                NaN  2020-04
# 1               1  5ea1997471c9de64fcfcf1145cadfff71ba37f21668d25...  2020-04
# 2               2                                                NaN  2020-04
# 3               3  0d8ee70dbd3096b4d07059d7f7c310fbf5de9cb7d44c31...  2020-04
# 4               4  cb4709a03d98dc63ba4c1771171bc7a9353097f5851d80...  2020-04
# ...           ...                                                ...      ...
# 27010       27010  b1dd0fef92ac4ea85ff20ab816d0502e86f84e6db39ed5...  2020-09
# 27011       27011  ddf41f20e6179b6ed39fd1490550207b5fcc95659dab15...  2020-09
# 27012       27012  db3017d52d1fc3feffd13c640b6e55b1a42fc7be1a9144...  2020-09
# 27013       27013  e4c189ac50cb9431c5dba2b34136527696baded6df216a...  2020-09
# 27014       27014  13169f64a9be46a157ba373d0e542e912d958a4ba1a2e0...  2020-09
#
# ...

# %%
list(crime.columns)
# Out:
# ['Unnamed: 0',
#  'Crime ID',
#  'Month',
#  'Falls within',
#  'Longitude',
#  'Latitude',
#  'Location',
#  'LSOA code',
#  'LSOA name',
#  'Crime type',
#  'Last outcome category',
#  'Context',
#  'Reported by']

# %%
crime = crime.rename(columns={"Unnamed: 0": "Number"})
list(crime.columns)
# Out:
# ['Number',
#  'Crime ID',
#  'Month',
#  'Falls within',
#  'Longitude',
#  'Latitude',
#  'Location',
#  'LSOA code',
#  'LSOA name',
#  'Crime type',
#  'Last outcome category',
#  'Context',
#  'Reported by']

# %%
# Replacing space in columns with underscore
crime.columns = [c.replace(' ', '_') for c in crime.columns]
list(crime.columns)
# Out:
# ['Number',
#  'Crime_ID',
#  'Month',
#  'Falls_within',
#  'Longitude',
#  'Latitude',
#  'Location',
#  'LSOA_code',
#  'LSOA_name',
#  'Crime_type',
#  'Last_outcome_category',
#  'Context',
#  'Reported_by']

# %%
# Checking for duplicated entries
crime_per_month =crime.groupby("Month").Crime_type.count()
crime_per_month = crime_per_month.reset_index()
crime_per_month.head()

crime[crime.duplicated(keep=False)]
# Out:
# Duplicated Entries: 1
#       Number Crime_ID Month Falls_within  Longitude  Latitude Location  \
# 4258    4258      NaN   NaN          NaN        NaN       NaN      NaN
# 4258    4258      NaN   NaN          NaN        NaN       NaN      NaN
#
#      LSOA_code LSOA_name Crime_type Last_outcome_category  Context Reported_by
# 4258       NaN       NaN        NaN                   NaN      NaN         NaN
# 4258       NaN       NaN        NaN                   NaN      NaN         NaN

# %%
crime.drop_duplicates(inplace = True)
print('Duplicated Entries: {}'.format(crime.duplicated().sum()))
# Out:
# Duplicated Entries: 0

# %%
crime.shape
# Out:
# (158897, 13)

# %%
crime.isnull().sum()
# Out:
# Number                        0
# Crime_ID                  29688
# Month                      1999
# Falls_within              31277
# Longitude                  5486
# Latitude                   5486
# Location                   1999
# LSOA_code                  5487
# LSOA_name                  5487
# Crime_type                 1999
# Last_outcome_category     31333
# Context                  158897
# Reported_by               23784
# dtype: int64

# %%
crime = crime[~crime['Crime_type'].isnull()]
crime.notna()
# Out:
#        Number  Crime_ID  Month  Falls_within  Longitude  Latitude  Location  \
# 0        True     False   True          True       True      True      True
# 1        True      True   True          True       True      True      True
# 2        True     False   True          True       True      True      True
# 3        True      True   True          True       True      True      True
# 4        True      True   True          True       True      True      True
# ...       ...       ...    ...           ...        ...       ...       ...
# 27010    True      True   True          True      False     False      True
# 27011    True      True   True          True      False     False      True
# 27012    True      True   True          True      False     False      True
# 27013    True      True   True          True      False     False      True
# 27014    True      True   True          True      False     False      True
#
# ...

# %%
# Information on column types and null values
info=pd.DataFrame(crime.dtypes).T.rename(index={0:'column type'})
info=info.append(pd.DataFrame(crime.isnull().sum()).T.rename(index={0:'null values (nb)'}))
info=info.append(pd.DataFrame(crime.isnull().sum()/crime.shape[0]*100).T.
                         rename(index={0:'null values (%)'}))
display(info)
# Out:
#                  Number   Crime_ID   Month Falls_within Longitude  Latitude  \
# column type       int64     object  object       object   float64   float64
# null values (nb)      0      29334       0        29278      3487      3487
# null values (%)     0.0  18.696223     0.0    18.660531  2.222463  2.222463
#
#                  Location LSOA_code LSOA_name Crime_type  \
# column type        object    object    object     object
# null values (nb)        0      3488      3488          0
# null values (%)       0.0    2.2231    2.2231        0.0
#
#                  Last_outcome_category  Context Reported_by
# column type                     object  float64      object
# null values (nb)                 29334   156898       21785
# null values (%)              18.696223    100.0   13.884817

# %%
# Count of crimes
crime_count = crime.groupby(by=['Crime_type'], as_index=False)['Month'].count()
crime_count = crime_count.rename(columns = {'Month':'Count of crimes'})
crime_count
# Out:
#                       Crime_type  Count of crimes
# 0          Anti-social behaviour            29314
# 1                  Bicycle theft             1031
# 2                       Burglary             7046
# 3      Criminal damage and arson            13054
# 4                          Drugs             4553
# 5                      Exclusive              119
# 6                    Other crime             3718
# 7                    Other theft             8319
# 8          Possession of weapons             1109
# 9                   Public order            17911
# 10                       Robbery             1176
# 11                   Shoplifting             4757
# 12         Theft from the person              866
# 13                 Vehicle crime             6442
# 14  Violence and sexual offences            57483

# %%
sns.barplot(x="Crime type",y="Count of crimes",data=temp2)
# Out:
# <AxesSubplot:xlabel='Crime type', ylabel='Count of crimes'>

# %%
fig = sns.barplot(x="Crime type",y="Count of crimes",data=temp2)
sns.set(rc = {'figure.figsize':(15,4)})
fig.figure.autofmt_xdate()

# %%
# Frequency of crimes per month
crime_per_month =crime.groupby("Month").Crime_type.count()
crime_per_month = crime_per_month.reset_index()
crime_per_month = crime_per_month.rename(columns = {'Crime_type':'Number of crimes'})
crime_per_month
# Out:
#      Month  Number of crimes
# 0  2020-04             21785
# 1  2020-05             23657
# 2  2020-06             26730
# 3  2020-07             29278
# 4  2020-08             29433
# 5  2020-09             26015

# %%
crime_per_month.plot( 'Month' , 'Number of crimes' )
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
crime_trend = crime[['Month','Crime_type']]
crime_trend
# Out:
#          Month                    Crime_type
# 0      2020-04         Anti-social behaviour
# 1      2020-04                      Burglary
# 2      2020-04         Anti-social behaviour
# 3      2020-04                   Shoplifting
# 4      2020-04  Violence and sexual offences
# ...        ...                           ...
# 27010  2020-09                   Other crime
# 27011  2020-09                   Other crime
# 27012  2020-09                   Other crime
# 27013  2020-09                   Other crime
# 27014  2020-09                   Other crime
#
# [156898 rows x 2 columns]

# %%
crime_trend['Crime_type'].unique()
# Out:
# array(['Anti-social behaviour', 'Burglary', 'Shoplifting',
#        'Violence and sexual offences', 'Drugs', 'Other theft',
#        'Possession of weapons', 'Public order', 'Vehicle crime',
#        'Robbery', 'Other crime', 'Criminal damage and arson',
#        'Bicycle theft', 'Theft from the person', 'Exclusive'],
#       dtype=object)

# %%
crime_count = crime_trend.groupby(['Month', 'Crime_type'],as_index=False).size() 
crime_count= crime_count.rename(columns = {'size':'Count'})
crime_count
# Out:
#       Month                    Crime_type  Count
# 0   2020-04         Anti-social behaviour   3398
# 1   2020-04                 Bicycle theft    121
# 2   2020-04                      Burglary   1089
# 3   2020-04     Criminal damage and arson   1726
# 4   2020-04                         Drugs    857
# ..      ...                           ...    ...
# 85  2020-09                       Robbery    231
# 86  2020-09                   Shoplifting    931
# 87  2020-09         Theft from the person    205
# 88  2020-09                 Vehicle crime   1152
# 89  2020-09  Violence and sexual offences   9397
#
# [90 rows x 3 columns]

# %%
crime_count['Month'] = pd.to_datetime(crime_count['Month'])
crime_count.dtypes
# Out:
# Month         datetime64[ns]
# Crime_type            object
# Count                  int64
# dtype: object

# %%
crime_count = crime_count.set_index('Month')
crime_count.tail()
# Out:
#                               Crime_type  Count
# Month
# 2020-09-01                       Robbery    231
# 2020-09-01                   Shoplifting    931
# 2020-09-01         Theft from the person    205
# 2020-09-01                 Vehicle crime   1152
# 2020-09-01  Violence and sexual offences   9397

# %%
crime_count.plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
crime_count
# Out:
#                            Crime_type  Count
# Month
# 2020-04-01      Anti-social behaviour   3398
# 2020-04-01              Bicycle theft    121
# 2020-04-01                   Burglary   1089
# 2020-04-01  Criminal damage and arson   1726
# 2020-04-01                      Drugs    857
# ...                               ...    ...
# 2020-09-01               Public order   2919
# 2020-09-01                    Robbery    231
# 2020-09-01                Shoplifting    931
# 2020-09-01      Theft from the person    205
# 2020-09-01              Vehicle crime   1152
#
# [80 rows x 2 columns]

# %%
import matplotlib
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]
from datetime import datetime
start_date = datetime(2020, 4, 1)
end_date = datetime(2020, 6, 1)
crime_count[(start_date <=crime_count.index) & (crime_count.index <= end_date)].plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
matplotlib.rcParams['figure.figsize'] = [12.0, 8.0]
start_date = datetime(2020, 7, 1)
end_date = datetime(2020, 9, 1)
crime_count[(start_date <=crime_count.index) & (crime_count.index <= end_date)].plot(grid=True)
# Out:
# <AxesSubplot:xlabel='Month'>

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Decompose the time series
decomposition = seasonal_decompose(crime_count['Count'], model='additive', period=1)
decomposition.plot()
plt.show()

# %%
decomposition = seasonal_decompose(crime_count['Count'], model='multiplicative', period=1)
decomposition.plot()
plt.show()

# %% [markdown]
# The trend is going up and down and seasonality is flat, not following a regular pattern.
#
# Time Series is usually used to predict future occurrences based on previous observed occurrence or values. Predicting what would happen in the stock market tomorrow.
#
# Time series helps us understand past trends so we can forecast and plan for the future. For example, you own a coffee shop, what you’d likely see is how many coffee you sell every day or month and when you want to see how your shop has performed over the past six months, you’re likely going to add all the six month sales. Now, what if you want to be able to forecast sales for the next six months or year. In this kind of scenario, the only variable known to you is time (either in seconds, minutes, days, months, years, etc) — hence you need Time Series Analysis to predict the other unknown variables like trends, seasonality,
#
# When the data are not trended and are not seasonal, a time series method will often generate a flat-line forecast reflecting the current sales level.
#
# Use machine learning techniques, such as k-fold cross-validation, to test the generalization accuracy of your model.
#
# A flat line in a seasonal plot in a time series can indicate that the data is not seasonal or trended, or that something has disrupted the trend or seasonality. A time series method, which uses an item's past demand history to generate a forecast, may produce a flat-line forecast when it's not predictable how the amounts will fluctuate based on the historic data. For example, if the historical data doesn't have strong seasonality, the forecasting model may find it difficult to predict the future and simply take the average of previous values
#
# If there seems to be a pattern in the way the points appear in the plot, or if they are mostly distributed on one side of the
# -axis, then a linear regression model is not appropriate to describe the relationship between
#  and

# %%
# Outlier Detection
sns.boxplot(crime_count["Count"])
plt.show()

# %%
# outlier treatment for Amount
Q1 = crime_count.Count.quantile(0.25)
Q3 = crime_count.Count.quantile(0.75)
IQR = Q3 - Q1
crime_count = crime_count[(crime_count.Count >= Q1 - 1.5*IQR) & (crime_count.Count <= Q3 + 1.5*IQR)]

# %%
# Outlier Detection
sns.boxplot(crime_count["Count"])
plt.show()
# Out:
# C:\Users\Eunice\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Standardizing variables



crime_count['Count'] = (crime_count['Count'] - crime_count['Count'].mean()) / crime_count['Count'].std()

# %%
crime_count
# Out:
#         Month                    Crime_type     Count
# 0  2020-04-01         Anti-social behaviour  0.665613
# 1  2020-04-01                 Bicycle theft -0.652588
# 2  2020-04-01                      Burglary -0.263202
# 3  2020-04-01     Criminal damage and arson -0.006964
# 4  2020-04-01                         Drugs -0.356526
# ..        ...                           ...       ...
# 85 2020-09-01                       Robbery -0.608340
# 86 2020-09-01                   Shoplifting -0.326759
# 87 2020-09-01         Theft from the person -0.618799
# 88 2020-09-01                 Vehicle crime -0.237860
# 89 2020-09-01  Violence and sexual offences  3.078761
#
# [90 rows x 3 columns]

# %%
crime_count = crime_count.set_index('Month')
crime_count.tail()
# Out:
#                               Crime_type     Count
# Month
# 2020-09-01                       Robbery -0.608340
# 2020-09-01                   Shoplifting -0.326759
# 2020-09-01         Theft from the person -0.618799
# 2020-09-01                 Vehicle crime -0.237860
# 2020-09-01  Violence and sexual offences  3.078761

# %%
sns.boxplot(crime_count["Count"])
plt.show()

# %%
def removal_box_plot(df, column, threshold):
    sns.boxplot(df[column])
    plt.title(f'Original Box Plot of {column}')
    plt.show()
 
    removed_outliers = df[df[column] <= threshold]
 
    sns.boxplot(removed_outliers[column])
    plt.title(f'Box Plot without Outliers of {column}')
    plt.show()
    return removed_outliers
 
threshold_value = 0.12
 
no_outliers = removal_box_plot(crime_count, 'Count', threshold_value)
# Out:
# C:\Users\Eunice\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Eunice\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
no_outliers
# Out:
#                            Crime_type     Count
# Month
# 2020-04-01              Bicycle theft -0.652588
# 2020-04-01                   Burglary -0.263202
# 2020-04-01  Criminal damage and arson -0.006964
# 2020-04-01                      Drugs -0.356526
# 2020-04-01                  Exclusive -0.693216
# ...                               ...       ...
# 2020-09-01      Possession of weapons -0.625235
# 2020-09-01                    Robbery -0.608340
# 2020-09-01                Shoplifting -0.326759
# 2020-09-01      Theft from the person -0.618799
# 2020-09-01              Vehicle crime -0.237860
#
# [68 rows x 2 columns]

# %%
decomposition = seasonal_decompose(no_outliers['Count'], model='Additive', period=1)
decomposition.plot()
plt.show()
